# %% [markdown]
# # import

# %%
import collections as cl
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage import measure
from skimage.segmentation import clear_border
from skimage.filters import threshold_otsu
from shapely.geometry import Polygon, MultiPolygon
from PIL import Image
import json
import cv2
import glob
import sys
import os
# print("finish import")

# %%
def info():
    tmp = cl.OrderedDict()
    tmp["description"] = "detect crater image num = 300000 For train"
    tmp["unity_info"] = "Random seed = 102125"
    tmp["url"] = "https://www.brain.kyutech.ac.jp/~tamukoh/"
    tmp["version"] = "3.0"
    tmp["year"] = 2021
    tmp["contributor"] = "yuga yano"
    tmp["data_created"] = "2021/10/13"
    tmp["image_size"] = "550 x 550"
    return tmp

def licenses():
    tmp = cl.OrderedDict()
    tmp["id"] = 1
    tmp["url"] = "https://www.brain.kyutech.ac.jp/~tamukoh/"
    tmp["name"] = "Kyutech.Tamlab.yano"
    return tmp

def categories():
    tmps = []
    sup = ["crater"]
    cat = ["crater"]
    for i in range(len(sup)):
        tmp = cl.OrderedDict()
        tmp["id"] = i+1
        tmp["name"] = cat[i]
        tmp["supercategory"] = sup[i]
        tmps.append(tmp)
    return tmps

# %%
def images(rgb_path, ignore, height, width):
    tmps = []
    files = glob.glob(rgb_path + "/*.png")
    files.sort()
    
    image_id = 0
    for i, file in enumerate(files):
        
        if i in ignore:
            pass
        else:
            tmp = cl.OrderedDict()
            tmp["license"] = 1
            tmp["id"] = image_id
            tmp["file_name"] = os.path.basename(file)
            tmp["width"] = width
            tmp["height"] = height
            tmp["date_captured"] = ""
            tmp["coco_url"] = "dummy_words"
            tmp["flickr_url"] = "dummy_words"
            tmps.append(tmp)
            image_id += 1
    return tmps

# %%
def create_sub_mask_annotation_con(contour, image_id, category_id, annotation_id, is_crowd, poly, area):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
#     contours = measure.find_contours(sub_mask, 0.5)

    segmentations = []
    polygons = []
#     for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
#     for i in range(len(contour)):
#         row, col = contour[i]
#         contour[i] = (col, row)

    # Make a polygon and simplify it
#     poly = Polygon(contour)
#     poly = poly.simplify(1.0, preserve_topology=False)
    polygons.append(poly)
    segmentation = np.array(poly.exterior.coords).ravel().tolist()
    segmentations.append(segmentation)

    # Combine the polygons to calculate the bounding box and area
    multi_poly = MultiPolygon(polygons)
    x, y, max_x, max_y = multi_poly.bounds
    width = max_x - x
    height = max_y - y
    bbox = (x, y, width, height)
#     area = multi_poly.area

    annotation = {
        'segmentation': segmentations,
        'iscrowd': is_crowd,
        'image_id': image_id,
        'category_id': category_id,
        'id': annotation_id,
        'bbox': bbox,
        'area': area
    }

    return annotation

# %%
def annotations(mask_path, thresh_areasize):
    print("===== make annotation start =====")
    mask_images = glob.glob(mask_path + "/*.png")
    mask_images.sort()

    # Define which colors match which categories in the images
    houseplant_id, book_id, bottle_id, lamp_id = [1, 2, 3, 4]
    crater_id = 1
    category_ids = {
        1: {
            '(77, 25, 255)': crater_id,
            '(0, 0, 255)': book_id,
        },
        2: {
            '(255, 255, 0)': bottle_id,
            '(255, 0, 128)': book_id,
            '(255, 100, 0)': lamp_id,
        }
    }

    is_crowd = 0

    # These ids will be automatically increased as we go
    annotation_id = 0
    image_id = 0
    
    rgb_image_id = 0
    # クレータが存在しない画像をデータセットから除外するため，除外する画像のidをリストで保存する
    ignore = []
    
    # Create the annotations
    annotations = []
    for mask_image_path in mask_images:
        mask_image_color = Image.open(mask_image_path).convert('RGB')
        mask_image_gray = cv2.imread(mask_image_path, 0)
        base_mask_image_name = os.path.basename(mask_image_path)
        contours = measure.find_contours(mask_image_gray, 0.5)

        # クレーターが存在しない画像が読み込まれた場合
        if len(contours) == 0:
            print("[warning_1]", base_mask_image_name, "no annotation")
            ignore.append(rgb_image_id)
            rgb_image_id += 1
            continue
    
        # 領域ごとに，ポリゴンとBboxを算出する
        for contour in contours:
            for i in range(len(contour)):
                row, col = contour[i]
                # x, yの入れ替えと小数点以下を丸める処理
                contour[i] = (round(col), round(row))
        
            polygons = []
            category_id = 1 # 今回はクラスがクレータしかないので，1で固定
            
            # ポリゴンによってエラーが出ることがあるので，try exceptで対応（エラーの原因不明）
            try:
                poly = Polygon(contour)
                poly = poly.simplify(1.0, preserve_topology=False)
#                 print(poly)
                
                # polygonが計算できた時のみ"annotations"に追加する
                if poly.is_empty == False:
                    polygons.append(poly)
                    multi_poly = MultiPolygon(polygons)
                    area = multi_poly.area
#                     print(area)
                    if area < thresh_areasize: # 小さすぎるクレーターのアノテーションデータは無視する
#                         print("[warning_3]", base_mask_image_name, "area size is too small. skipping!")
                        pass
                    else:
                        annotation = create_sub_mask_annotation_con(contour, image_id, category_id, annotation_id, is_crowd, poly, area)
                        annotations.append(annotation)
                        annotation_id += 1
            except:
                print("[warning_2]", base_mask_image_name, "skipping the counter")
        
        image_id += 1
        rgb_image_id += 1
        if image_id % 100 == 0:
            print("progress: ", image_id)
            
    print(len(mask_images),"個のファイルのうち" ,len(ignore), "個はクレータが存在しないため無視しました")
    print("最終的なデータ数は", len(mask_images)-len(ignore), "です")
    print("===== create annotation complete!! =====")
#     print(ignore)
    return annotations, ignore

# %% [markdown]
# # 実行関数

# %%
if __name__ == "__main__":
    
    # フォルダパス
    base_path = "/home/yuga/.config/unity3d/DefaultCompany/PerceptionURP/train/"
#     base_path = "/home/yuga/.config/unity3d/DefaultCompany/PerceptionURP/tests/ZED_720p/"
    
    mask_path = base_path + "semas"
    rgb_path = base_path + "images"
    
    # データの画像サイズ
    height = 550
    width = 550
    
    # 無視するアノテーションのエリアサイズ
    # 小さすぎるクレータのアノテーションデータはノイズになっているが可能性あるため除外する
    thresh_areasize = 1
    
    query_list = ["info", "licenses", "images", "annotations", "categories", "segment_info"]
    js = cl.OrderedDict()
    for i in range(len(query_list)):
        tmp = ""
        # Info
        if query_list[i] == "info":
            tmp = info()

        # licenses
        elif query_list[i] == "licenses":
            tmp = licenses()

#         elif query_list[i] == "images":
#             tmp = images(rgb_path)

# fix me
        elif query_list[i] == "annotations":
            tmp, ignore = annotations(mask_path, thresh_areasize)
            tmp_img = ""
            tmp_img = images(rgb_path, ignore, height, width)
            js[query_list[i-1]] = tmp_img

        elif query_list[i] == "categories":
            tmp = categories()

        # save it
        js[query_list[i]] = tmp

    print("finish")
#     print(js["images"])
# Out:
# ===== make annotation start =====
# [warning_1] segmentation_10.png no annotation
# [warning_1] segmentation_100.png no annotation
# [warning_1] segmentation_100001.png no annotation
# [warning_1] segmentation_100002.png no annotation
# [warning_1] segmentation_10002.png no annotation
# [warning_1] segmentation_100024.png no annotation
# [warning_1] segmentation_100027.png no annotation
# [warning_1] segmentation_100044.png no annotation
# [warning_1] segmentation_10005.png no annotation
# [warning_1] segmentation_100055.png no annotation
# [warning_1] segmentation_100067.png no annotation
# [warning_1] segmentation_10008.png no annotation
# [warning_1] segmentation_100083.png no annotation
# [warning_1] segmentation_100093.png no annotation
# progress:  100
# [warning_1] segmentation_100104.png no annotation
# [warning_1] segmentation_10011.png no annotation
# [warning_1] segmentation_100114.png no annotation
# [warning_1] segmentation_100129.png no annotation
# [warning_1] segmentation_100167.png no annotation
# [warning_1] segmentation_10017.png no annotation
# [warning_1] segmentation_100173.png no annotation
# [warning_1] segmentation_100177.png no annotation
# [warning_1] segmentation_100187.png no annotation
# progress:  200
# [warning_1] segmentation_100222.png no annotation
# [warning_1] segmentation_100232.png no annotation
# [warning_1] segmentation_100236.png no annotation
# [warning_1] segmentation_100247.png no annotation
# [warning_1] segmentation_100248.png no annotation
# [warning_1] segmentation_100266.png no annotation
# [warning_1] segmentation_100270.png no annotation
# [warning_1] segmentation_100272.png no annotation
# [warning_1] segmentation_100277.png no annotation
# [warning_1] segmentation_100282.png no annotation
# [warning_1] segmentation_100284.png no annotation
# [warning_1] segmentation_100287.png no annotation
# [warning_1] segmentation_100292.png no annotation
# [warning_1] segmentation_100296.png no annotation
# progress:  300
# [warning_1] segmentation_100317.png no annotation
# [warning_1] segmentation_100326.png no annotation
# [warning_1] segmentation_100330.png no annotation
# [warning_1] segmentation_100346.png no annotation
# [warning_1] segmentation_100360.png no annotation
# [warning_1] segmentation_100363.png no annotation
# [warning_1] segmentation_100380.png no annotation
# [warning_1] segmentation_100386.png no annotation
# [warning_1] segmentation_100387.png no annotation
# [warning_1] segmentation_100389.png no annotation
# [warning_1] segmentation_100392.png no annotation
# [warning_1] segmentation_100395.png no annotation
# [warning_1] segmentation_100397.png no annotation
# [warning_1] segmentation_100398.png no annotation
# progress:  400
# [warning_1] segmentation_100420.png no annotation
# [warning_1] segmentation_100433.png no annotation
# [warning_1] segmentation_100444.png no annotation
# [warning_1] segmentation_100445.png no annotation
# [warning_2] segmentation_100450.png skipping the counter
# [warning_1] segmentation_10046.png no annotation
# [warning_1] segmentation_100464.png no annotation
# [warning_1] segmentation_100472.png no annotation
# [warning_1] segmentation_10048.png no annotation
# [warning_1] segmentation_100490.png no annotation
# [warning_1] segmentation_100496.png no annotation
# progress:  500
# [warning_1] segmentation_100504.png no annotation
# [warning_1] segmentation_100505.png no annotation
# [warning_1] segmentation_100518.png no annotation
# [warning_1] segmentation_100531.png no annotation
# [warning_1] segmentation_10055.png no annotation
# [warning_1] segmentation_100566.png no annotation
# [warning_1] segmentation_100570.png no annotation
# [warning_1] segmentation_100575.png no annotation
# [warning_1] segmentation_100582.png no annotation
# [warning_1] segmentation_100586.png no annotation
# [warning_1] segmentation_100596.png no annotation
# progress:  600
# [warning_1] segmentation_10062.png no annotation
# [warning_1] segmentation_100622.png no annotation
# [warning_1] segmentation_100624.png no annotation
# [warning_1] segmentation_100629.png no annotation
# [warning_1] segmentation_10064.png no annotation
# [warning_1] segmentation_100660.png no annotation
# [warning_1] segmentation_100663.png no annotation
# [warning_1] segmentation_100666.png no annotation
# [warning_1] segmentation_100668.png no annotation
# [warning_1] segmentation_100684.png no annotation
# [warning_1] segmentation_100687.png no annotation
# [warning_1] segmentation_100690.png no annotation
# progress:  700
# [warning_1] segmentation_100714.png no annotation
# [warning_1] segmentation_100728.png no annotation
# [warning_1] segmentation_100732.png no annotation
# [warning_1] segmentation_100742.png no annotation
# [warning_1] segmentation_100752.png no annotation
# [warning_1] segmentation_100753.png no annotation
# [warning_1] segmentation_100773.png no annotation
# [warning_1] segmentation_100778.png no annotation
# [warning_1] segmentation_10079.png no annotation
# [warning_1] segmentation_10080.png no annotation
# [warning_1] segmentation_100801.png no annotation
# progress:  800
# [warning_1] segmentation_100813.png no annotation
# [warning_1] segmentation_100817.png no annotation
# [warning_1] segmentation_100834.png no annotation
# [warning_2] segmentation_100841.png skipping the counter
# [warning_1] segmentation_100851.png no annotation
# [warning_1] segmentation_100859.png no annotation
# [warning_1] segmentation_100863.png no annotation
# [warning_1] segmentation_100867.png no annotation
# [warning_1] segmentation_100874.png no annotation
# [warning_1] segmentation_100881.png no annotation
# [warning_1] segmentation_100889.png no annotation
# [warning_1] segmentation_10090.png no annotation
# [warning_1] segmentation_100902.png no annotation
# progress:  900
# [warning_1] segmentation_100906.png no annotation
# [warning_1] segmentation_100912.png no annotation
# [warning_1] segmentation_100924.png no annotation
# [warning_1] segmentation_100927.png no annotation
# [warning_2] segmentation_100947.png skipping the counter
# [warning_1] segmentation_100949.png no annotation
# [warning_1] segmentation_100951.png no annotation
# [warning_1] segmentation_100972.png no annotation
# [warning_1] segmentation_100994.png no annotation
# [warning_1] segmentation_100996.png no annotation
# progress:  1000
# [warning_1] segmentation_101005.png no annotation
# [warning_1] segmentation_101006.png no annotation
# [warning_1] segmentation_10101.png no annotation
# [warning_1] segmentation_101010.png no annotation
# [warning_1] segmentation_101016.png no annotation
# [warning_1] segmentation_101033.png no annotation
# [warning_1] segmentation_10104.png no annotation
# [warning_1] segmentation_101042.png no annotation
# [warning_1] segmentation_101048.png no annotation
# [warning_1] segmentation_101054.png no annotation
# [warning_1] segmentation_101068.png no annotation
# [warning_1] segmentation_101078.png no annotation
# [warning_1] segmentation_101080.png no annotation
# [warning_1] segmentation_101088.png no annotation
# [warning_1] segmentation_10109.png no annotation
# progress:  1100
# [warning_2] segmentation_10112.png skipping the counter
# [warning_1] segmentation_101162.png no annotation
# [warning_1] segmentation_101166.png no annotation
# [warning_1] segmentation_101171.png no annotation
# [warning_1] segmentation_101178.png no annotation
# [warning_1] segmentation_101198.png no annotation
# progress:  1200
# [warning_1] segmentation_10120.png no annotation
# [warning_1] segmentation_101205.png no annotation
# [warning_1] segmentation_101206.png no annotation
# [warning_1] segmentation_101221.png no annotation
# [warning_1] segmentation_101225.png no annotation
# [warning_1] segmentation_101226.png no annotation
# [warning_1] segmentation_101229.png no annotation
# [warning_1] segmentation_101240.png no annotation
# [warning_1] segmentation_101243.png no annotation
# [warning_2] segmentation_101251.png skipping the counter
# [warning_1] segmentation_101269.png no annotation
# [warning_1] segmentation_10127.png no annotation
# [warning_1] segmentation_101273.png no annotation
# [warning_1] segmentation_101288.png no annotation
# progress:  1300
# [warning_1] segmentation_101310.png no annotation
# [warning_1] segmentation_101315.png no annotation
# [warning_1] segmentation_101328.png no annotation
# [warning_1] segmentation_101333.png no annotation
# [warning_1] segmentation_101336.png no annotation
# [warning_1] segmentation_10134.png no annotation
# [warning_1] segmentation_101342.png no annotation
# [warning_1] segmentation_101360.png no annotation
# [warning_1] segmentation_101362.png no annotation
# [warning_1] segmentation_101370.png no annotation
# [warning_1] segmentation_101371.png no annotation
# [warning_1] segmentation_101378.png no annotation
# [warning_2] segmentation_10139.png skipping the counter
# [warning_1] segmentation_101391.png no annotation
# [warning_1] segmentation_1014.png no annotation
# [warning_1] segmentation_101400.png no annotation
# progress:  1400
# [warning_1] segmentation_101409.png no annotation
# [warning_1] segmentation_10141.png no annotation
# [warning_1] segmentation_101419.png no annotation
# [warning_1] segmentation_101421.png no annotation
# [warning_1] segmentation_101440.png no annotation
# [warning_1] segmentation_101454.png no annotation
# [warning_1] segmentation_101459.png no annotation
# [warning_1] segmentation_101466.png no annotation
# [warning_1] segmentation_101484.png no annotation
# [warning_1] segmentation_101491.png no annotation
# progress:  1500
# [warning_2] segmentation_101507.png skipping the counter
# [warning_1] segmentation_101515.png no annotation
# [warning_1] segmentation_101517.png no annotation
# [warning_1] segmentation_101518.png no annotation
# [warning_1] segmentation_101525.png no annotation
# [warning_1] segmentation_101528.png no annotation
# [warning_1] segmentation_101560.png no annotation
# [warning_1] segmentation_101575.png no annotation
# [warning_1] segmentation_101576.png no annotation
# [warning_1] segmentation_101580.png no annotation
# [warning_1] segmentation_101581.png no annotation
# [warning_1] segmentation_101587.png no annotation
# [warning_1] segmentation_101602.png no annotation
# [warning_1] segmentation_101604.png no annotation
# progress:  1600
# [warning_1] segmentation_101623.png no annotation
# [warning_1] segmentation_101653.png no annotation
# [warning_1] segmentation_101662.png no annotation
# [warning_1] segmentation_101666.png no annotation
# [warning_1] segmentation_101667.png no annotation
# [warning_1] segmentation_101681.png no annotation
# [warning_1] segmentation_101694.png no annotation
# progress:  1700
# [warning_2] segmentation_10174.png skipping the counter
# [warning_1] segmentation_101757.png no annotation
# [warning_1] segmentation_101764.png no annotation
# [warning_1] segmentation_101778.png no annotation
# [warning_1] segmentation_101788.png no annotation
# [warning_1] segmentation_101794.png no annotation
# [warning_1] segmentation_101795.png no annotation
# progress:  1800
# [warning_1] segmentation_101827.png no annotation
# [warning_1] segmentation_101834.png no annotation
# [warning_1] segmentation_101856.png no annotation
# [warning_1] segmentation_101861.png no annotation
# [warning_1] segmentation_101870.png no annotation
# [warning_1] segmentation_101878.png no annotation
# progress:  1900
# [warning_1] segmentation_101898.png no annotation
# [warning_1] segmentation_101907.png no annotation
# [warning_1] segmentation_101915.png no annotation
# [warning_1] segmentation_101928.png no annotation
# [warning_1] segmentation_101930.png no annotation
# [warning_1] segmentation_101931.png no annotation
# [warning_1] segmentation_10194.png no annotation
# [warning_1] segmentation_101946.png no annotation
# [warning_1] segmentation_101948.png no annotation
# [warning_1] segmentation_101960.png no annotation
# [warning_1] segmentation_101962.png no annotation
# [warning_1] segmentation_101965.png no annotation
# [warning_1] segmentation_101967.png no annotation
# [warning_1] segmentation_101981.png no annotation
# [warning_1] segmentation_101989.png no annotation
# [warning_1] segmentation_101993.png no annotation
# progress:  2000
# [warning_1] segmentation_102008.png no annotation
# [warning_1] segmentation_102011.png no annotation
# [warning_1] segmentation_102013.png no annotation
# [warning_1] segmentation_102014.png no annotation
# [warning_1] segmentation_102017.png no annotation
# [warning_1] segmentation_102037.png no annotation
# [warning_1] segmentation_10204.png no annotation
# [warning_1] segmentation_102042.png no annotation
# [warning_1] segmentation_102044.png no annotation
# [warning_1] segmentation_102052.png no annotation
# [warning_1] segmentation_102058.png no annotation
# [warning_1] segmentation_10207.png no annotation
# [warning_1] segmentation_102076.png no annotation
# [warning_1] segmentation_102082.png no annotation
# [warning_1] segmentation_102095.png no annotation
# [warning_1] segmentation_102099.png no annotation
# progress:  2100
# [warning_1] segmentation_102129.png no annotation
# [warning_1] segmentation_102139.png no annotation
# [warning_1] segmentation_102141.png no annotation
# [warning_1] segmentation_102146.png no annotation
# [warning_1] segmentation_10216.png no annotation
# [warning_1] segmentation_102163.png no annotation
# [warning_1] segmentation_102187.png no annotation
# [warning_1] segmentation_102191.png no annotation
# progress:  2200
# [warning_1] segmentation_102219.png no annotation
# [warning_1] segmentation_102234.png no annotation
# [warning_1] segmentation_102237.png no annotation
# [warning_1] segmentation_102257.png no annotation
# [warning_1] segmentation_102258.png no annotation
# [warning_1] segmentation_102263.png no annotation
# [warning_1] segmentation_102268.png no annotation
# [warning_1] segmentation_102273.png no annotation
# [warning_1] segmentation_102290.png no annotation
# [warning_1] segmentation_102296.png no annotation
# progress:  2300
# [warning_1] segmentation_10230.png no annotation
# [warning_1] segmentation_102318.png no annotation
# [warning_1] segmentation_102325.png no annotation
# [warning_1] segmentation_102327.png no annotation
# [warning_1] segmentation_102334.png no annotation
# [warning_1] segmentation_102336.png no annotation
# [warning_1] segmentation_102339.png no annotation
# [warning_1] segmentation_102342.png no annotation
# [warning_1] segmentation_102352.png no annotation
# [warning_1] segmentation_102359.png no annotation
# [warning_2] segmentation_10238.png skipping the counter
# [warning_1] segmentation_102389.png no annotation
# [warning_1] segmentation_102397.png no annotation
# [warning_1] segmentation_102398.png no annotation
# [warning_1] segmentation_1024.png no annotation
# [warning_1] segmentation_10240.png no annotation
# progress:  2400
# [warning_1] segmentation_102407.png no annotation
# [warning_1] segmentation_102416.png no annotation
# [warning_1] segmentation_102431.png no annotation
# [warning_1] segmentation_102433.png no annotation
# [warning_1] segmentation_102445.png no annotation
# [warning_1] segmentation_102447.png no annotation
# [warning_1] segmentation_102456.png no annotation
# [warning_1] segmentation_102482.png no annotation
# [warning_1] segmentation_102487.png no annotation
# progress:  2500
# [warning_1] segmentation_102502.png no annotation
# [warning_1] segmentation_10252.png no annotation
# [warning_1] segmentation_102521.png no annotation
# [warning_1] segmentation_102522.png no annotation
# [warning_1] segmentation_102533.png no annotation
# [warning_1] segmentation_102545.png no annotation
# [warning_1] segmentation_102553.png no annotation
# [warning_1] segmentation_102558.png no annotation
# [warning_1] segmentation_102563.png no annotation
# [warning_1] segmentation_102571.png no annotation
# [warning_1] segmentation_10258.png no annotation
# [warning_1] segmentation_102582.png no annotation
# [warning_1] segmentation_102599.png no annotation
# progress:  2600
# [warning_1] segmentation_102605.png no annotation
# [warning_1] segmentation_102609.png no annotation
# [warning_1] segmentation_102614.png no annotation
# [warning_1] segmentation_102616.png no annotation
# [warning_1] segmentation_102624.png no annotation
# [warning_1] segmentation_102636.png no annotation
# [warning_1] segmentation_102639.png no annotation
# [warning_1] segmentation_102669.png no annotation
# [warning_1] segmentation_102671.png no annotation
# [warning_1] segmentation_102677.png no annotation
# [warning_1] segmentation_102679.png no annotation
# [warning_1] segmentation_102691.png no annotation
# [warning_1] segmentation_102695.png no annotation
# [warning_1] segmentation_102698.png no annotation
# [warning_1] segmentation_102703.png no annotation
# progress:  2700
# [warning_1] segmentation_102713.png no annotation
# [warning_1] segmentation_102725.png no annotation
# [warning_1] segmentation_102733.png no annotation
# [warning_1] segmentation_102746.png no annotation
# [warning_1] segmentation_102751.png no annotation
# [warning_1] segmentation_102757.png no annotation
# [warning_1] segmentation_102764.png no annotation
# [warning_2] segmentation_102766.png skipping the counter
# [warning_1] segmentation_102768.png no annotation
# [warning_1] segmentation_102771.png no annotation
# [warning_1] segmentation_102775.png no annotation
# [warning_1] segmentation_102793.png no annotation
# [warning_1] segmentation_102797.png no annotation
# progress:  2800
# [warning_1] segmentation_102817.png no annotation
# [warning_1] segmentation_102827.png no annotation
# [warning_1] segmentation_10283.png no annotation
# [warning_1] segmentation_102837.png no annotation
# [warning_1] segmentation_10284.png no annotation
# [warning_1] segmentation_102847.png no annotation
# [warning_1] segmentation_102852.png no annotation
# [warning_1] segmentation_102857.png no annotation
# [warning_1] segmentation_102860.png no annotation
# [warning_1] segmentation_102869.png no annotation
# [warning_1] segmentation_10287.png no annotation
# progress:  2900
# [warning_1] segmentation_102918.png no annotation
# [warning_1] segmentation_102935.png no annotation
# [warning_1] segmentation_102954.png no annotation
# [warning_1] segmentation_102965.png no annotation
# [warning_1] segmentation_102982.png no annotation
# [warning_1] segmentation_102983.png no annotation
# [warning_1] segmentation_102984.png no annotation
# [warning_1] segmentation_102985.png no annotation
# [warning_1] segmentation_102988.png no annotation
# [warning_1] segmentation_102991.png no annotation
# [warning_1] segmentation_102998.png no annotation
# [warning_1] segmentation_10300.png no annotation
# progress:  3000
# [warning_1] segmentation_103008.png no annotation
# [warning_1] segmentation_103025.png no annotation
# [warning_1] segmentation_103029.png no annotation
# [warning_1] segmentation_10303.png no annotation
# [warning_1] segmentation_103030.png no annotation
# [warning_1] segmentation_10304.png no annotation
# [warning_1] segmentation_103044.png no annotation
# [warning_1] segmentation_103045.png no annotation
# [warning_1] segmentation_103046.png no annotation
# [warning_1] segmentation_103056.png no annotation
# [warning_1] segmentation_10306.png no annotation
# [warning_1] segmentation_103067.png no annotation
# [warning_1] segmentation_103070.png no annotation
# [warning_1] segmentation_103071.png no annotation
# [warning_1] segmentation_103074.png no annotation
# [warning_1] segmentation_10309.png no annotation
# progress:  3100
# [warning_1] segmentation_103111.png no annotation
# [warning_1] segmentation_103118.png no annotation
# [warning_1] segmentation_103121.png no annotation
# [warning_1] segmentation_103122.png no annotation
# [warning_1] segmentation_103130.png no annotation
# [warning_1] segmentation_103134.png no annotation
# [warning_1] segmentation_103136.png no annotation
# [warning_1] segmentation_103140.png no annotation
# [warning_1] segmentation_103148.png no annotation
# [warning_1] segmentation_103162.png no annotation
# [warning_1] segmentation_103165.png no annotation
# [warning_1] segmentation_103169.png no annotation
# [warning_1] segmentation_103185.png no annotation
# [warning_1] segmentation_103187.png no annotation
# progress:  3200
# [warning_1] segmentation_103219.png no annotation
# [warning_1] segmentation_103221.png no annotation
# [warning_1] segmentation_103227.png no annotation
# [warning_1] segmentation_10323.png no annotation
# [warning_1] segmentation_10325.png no annotation
# [warning_1] segmentation_103254.png no annotation
# [warning_1] segmentation_103271.png no annotation
# [warning_1] segmentation_103276.png no annotation
# [warning_1] segmentation_103286.png no annotation
# [warning_1] segmentation_103289.png no annotation
# [warning_1] segmentation_103295.png no annotation
# [warning_1] segmentation_103298.png no annotation
# [warning_1] segmentation_103305.png no annotation
# [warning_1] segmentation_103311.png no annotation
# progress:  3300
# [warning_1] segmentation_103318.png no annotation
# [warning_1] segmentation_10332.png no annotation
# [warning_1] segmentation_103323.png no annotation
# [warning_1] segmentation_103331.png no annotation
# [warning_1] segmentation_10335.png no annotation
# [warning_1] segmentation_103355.png no annotation
# [warning_1] segmentation_103361.png no annotation
# [warning_1] segmentation_103362.png no annotation
# [warning_1] segmentation_103366.png no annotation
# [warning_1] segmentation_103375.png no annotation
# [warning_1] segmentation_10338.png no annotation
# [warning_1] segmentation_103384.png no annotation
# [warning_1] segmentation_103396.png no annotation
# [warning_1] segmentation_1034.png no annotation
# progress:  3400
# [warning_1] segmentation_103445.png no annotation
# [warning_1] segmentation_103446.png no annotation
# [warning_1] segmentation_103455.png no annotation
# [warning_1] segmentation_103460.png no annotation
# [warning_1] segmentation_103462.png no annotation
# [warning_1] segmentation_103466.png no annotation
# [warning_1] segmentation_103469.png no annotation
# [warning_1] segmentation_103502.png no annotation
# progress:  3500
# [warning_1] segmentation_103530.png no annotation
# [warning_2] segmentation_103534.png skipping the counter
# [warning_1] segmentation_10354.png no annotation
# [warning_1] segmentation_103559.png no annotation
# [warning_1] segmentation_103568.png no annotation
# [warning_1] segmentation_103573.png no annotation
# [warning_1] segmentation_103581.png no annotation
# [warning_1] segmentation_103592.png no annotation
# [warning_1] segmentation_103597.png no annotation
# [warning_1] segmentation_103604.png no annotation
# [warning_1] segmentation_103608.png no annotation
# progress:  3600
# [warning_1] segmentation_103617.png no annotation
# [warning_1] segmentation_103620.png no annotation
# [warning_1] segmentation_103625.png no annotation
# [warning_1] segmentation_103643.png no annotation
# [warning_1] segmentation_103649.png no annotation
# [warning_1] segmentation_103651.png no annotation
# [warning_2] segmentation_103652.png skipping the counter
# [warning_1] segmentation_103653.png no annotation
# [warning_1] segmentation_10366.png no annotation
# [warning_1] segmentation_103675.png no annotation
# [warning_1] segmentation_103677.png no annotation
# [warning_1] segmentation_103682.png no annotation
# [warning_1] segmentation_103684.png no annotation
# [warning_1] segmentation_10369.png no annotation
# [warning_1] segmentation_103692.png no annotation
# [warning_1] segmentation_103696.png no annotation
# [warning_1] segmentation_103698.png no annotation
# progress:  3700
# [warning_1] segmentation_103720.png no annotation
# [warning_1] segmentation_103749.png no annotation
# [warning_1] segmentation_103753.png no annotation
# [warning_1] segmentation_103763.png no annotation
# [warning_1] segmentation_103765.png no annotation
# [warning_1] segmentation_103767.png no annotation
# [warning_1] segmentation_103790.png no annotation
# [warning_1] segmentation_10380.png no annotation
# [warning_1] segmentation_103809.png no annotation
# progress:  3800
# [warning_1] segmentation_103823.png no annotation
# [warning_2] segmentation_103833.png skipping the counter
# [warning_1] segmentation_103847.png no annotation
# [warning_1] segmentation_103867.png no annotation
# [warning_1] segmentation_103874.png no annotation
# [warning_1] segmentation_103877.png no annotation
# [warning_1] segmentation_103902.png no annotation
# progress:  3900
# [warning_1] segmentation_103915.png no annotation
# [warning_1] segmentation_10394.png no annotation
# [warning_1] segmentation_103950.png no annotation
# [warning_1] segmentation_103954.png no annotation
# [warning_1] segmentation_103962.png no annotation
# [warning_1] segmentation_103965.png no annotation
# [warning_1] segmentation_103972.png no annotation
# [warning_1] segmentation_103982.png no annotation
# [warning_1] segmentation_104006.png no annotation
# progress:  4000
# [warning_1] segmentation_10402.png no annotation
# [warning_1] segmentation_104020.png no annotation
# [warning_1] segmentation_104026.png no annotation
# [warning_1] segmentation_104029.png no annotation
# [warning_1] segmentation_104030.png no annotation
# [warning_1] segmentation_104034.png no annotation
# [warning_1] segmentation_104038.png no annotation
# [warning_1] segmentation_104045.png no annotation
# [warning_1] segmentation_104046.png no annotation
# [warning_1] segmentation_104053.png no annotation
# [warning_1] segmentation_104063.png no annotation
# [warning_1] segmentation_104066.png no annotation
# [warning_1] segmentation_104067.png no annotation
# [warning_1] segmentation_104087.png no annotation
# [warning_1] segmentation_104102.png no annotation
# progress:  4100
# [warning_1] segmentation_104116.png no annotation
# [warning_1] segmentation_104122.png no annotation
# [warning_1] segmentation_104130.png no annotation
# [warning_1] segmentation_104135.png no annotation
# [warning_1] segmentation_104144.png no annotation
# [warning_1] segmentation_104153.png no annotation
# [warning_1] segmentation_104164.png no annotation
# [warning_1] segmentation_104168.png no annotation
# [warning_1] segmentation_10417.png no annotation
# [warning_1] segmentation_104176.png no annotation
# [warning_1] segmentation_104193.png no annotation
# [warning_1] segmentation_10421.png no annotation
# [warning_1] segmentation_104214.png no annotation
# progress:  4200
# [warning_1] segmentation_104216.png no annotation
# [warning_1] segmentation_104217.png no annotation
# [warning_1] segmentation_104219.png no annotation
# [warning_1] segmentation_104224.png no annotation
# [warning_1] segmentation_104234.png no annotation
# [warning_1] segmentation_104251.png no annotation
# [warning_1] segmentation_104269.png no annotation
# [warning_1] segmentation_104270.png no annotation
# [warning_2] segmentation_104277.png skipping the counter
# [warning_1] segmentation_10428.png no annotation
# [warning_1] segmentation_104308.png no annotation
# [warning_1] segmentation_104309.png no annotation
# progress:  4300
# [warning_1] segmentation_10432.png no annotation
# [warning_1] segmentation_104333.png no annotation
# [warning_1] segmentation_104343.png no annotation
# [warning_1] segmentation_104345.png no annotation
# [warning_1] segmentation_104352.png no annotation
# [warning_1] segmentation_104353.png no annotation
# [warning_1] segmentation_104395.png no annotation
# [warning_1] segmentation_104396.png no annotation
# [warning_1] segmentation_104403.png no annotation
# progress:  4400
# [warning_1] segmentation_104422.png no annotation
# [warning_1] segmentation_104430.png no annotation
# [warning_1] segmentation_104432.png no annotation
# [warning_1] segmentation_104446.png no annotation
# [warning_1] segmentation_10445.png no annotation
# [warning_1] segmentation_104453.png no annotation
# [warning_1] segmentation_104457.png no annotation
# [warning_1] segmentation_104462.png no annotation
# [warning_1] segmentation_104476.png no annotation
# [warning_1] segmentation_104499.png no annotation
# progress:  4500
# [warning_1] segmentation_104527.png no annotation
# [warning_2] segmentation_104533.png skipping the counter
# [warning_1] segmentation_104538.png no annotation
# [warning_1] segmentation_104548.png no annotation
# [warning_1] segmentation_104561.png no annotation
# [warning_1] segmentation_104579.png no annotation
# [warning_1] segmentation_104597.png no annotation
# [warning_1] segmentation_104604.png no annotation
# progress:  4600
# [warning_1] segmentation_104617.png no annotation
# [warning_1] segmentation_104630.png no annotation
# [warning_1] segmentation_104639.png no annotation
# [warning_1] segmentation_104642.png no annotation
# [warning_1] segmentation_104645.png no annotation
# [warning_1] segmentation_104653.png no annotation
# [warning_1] segmentation_104668.png no annotation
# [warning_1] segmentation_104670.png no annotation
# [warning_1] segmentation_104675.png no annotation
# [warning_1] segmentation_104691.png no annotation
# [warning_1] segmentation_10470.png no annotation
# [warning_1] segmentation_104703.png no annotation
# [warning_1] segmentation_104705.png no annotation
# progress:  4700
# [warning_1] segmentation_104714.png no annotation
# [warning_1] segmentation_104729.png no annotation
# [warning_1] segmentation_104737.png no annotation
# [warning_1] segmentation_104739.png no annotation
# [warning_1] segmentation_104743.png no annotation
# [warning_1] segmentation_104744.png no annotation
# [warning_1] segmentation_104758.png no annotation
# [warning_1] segmentation_104761.png no annotation
# [warning_1] segmentation_104773.png no annotation
# [warning_1] segmentation_104776.png no annotation
# [warning_1] segmentation_104781.png no annotation
# [warning_1] segmentation_104794.png no annotation
# [warning_1] segmentation_104799.png no annotation
# [warning_1] segmentation_104810.png no annotation
# [warning_1] segmentation_104811.png no annotation
# [warning_1] segmentation_104812.png no annotation
# progress:  4800
# [warning_1] segmentation_10482.png no annotation
# [warning_1] segmentation_104820.png no annotation
# [warning_1] segmentation_104828.png no annotation
# [warning_1] segmentation_104832.png no annotation
# [warning_1] segmentation_104834.png no annotation
# [warning_1] segmentation_104840.png no annotation
# [warning_1] segmentation_104843.png no annotation
# [warning_1] segmentation_104847.png no annotation
# [warning_2] segmentation_104849.png skipping the counter
# [warning_1] segmentation_104884.png no annotation
# [warning_1] segmentation_104899.png no annotation
# [warning_1] segmentation_104903.png no annotation
# [warning_1] segmentation_104904.png no annotation
# [warning_1] segmentation_104907.png no annotation
# [warning_1] segmentation_10491.png no annotation
# [warning_1] segmentation_104913.png no annotation
# progress:  4900
# [warning_1] segmentation_104928.png no annotation
# [warning_1] segmentation_104929.png no annotation
# [warning_1] segmentation_104942.png no annotation
# [warning_1] segmentation_104950.png no annotation
# [warning_1] segmentation_104969.png no annotation
# [warning_1] segmentation_104974.png no annotation
# [warning_1] segmentation_104987.png no annotation
# [warning_1] segmentation_105012.png no annotation
# progress:  5000
# [warning_1] segmentation_105016.png no annotation
# [warning_1] segmentation_105020.png no annotation
# [warning_1] segmentation_105042.png no annotation
# [warning_1] segmentation_105049.png no annotation
# [warning_1] segmentation_105055.png no annotation
# [warning_1] segmentation_105058.png no annotation
# [warning_1] segmentation_105065.png no annotation
# [warning_1] segmentation_105066.png no annotation
# [warning_1] segmentation_105087.png no annotation
# [warning_1] segmentation_105092.png no annotation
# [warning_1] segmentation_105094.png no annotation
# [warning_1] segmentation_105104.png no annotation
# [warning_1] segmentation_10511.png no annotation
# progress:  5100
# [warning_1] segmentation_105118.png no annotation
# [warning_1] segmentation_105133.png no annotation
# [warning_1] segmentation_105156.png no annotation
# [warning_1] segmentation_105158.png no annotation
# [warning_1] segmentation_105163.png no annotation
# [warning_1] segmentation_105177.png no annotation
# [warning_1] segmentation_105178.png no annotation
# [warning_1] segmentation_105192.png no annotation
# [warning_1] segmentation_105199.png no annotation
# [warning_1] segmentation_10520.png no annotation
# [warning_1] segmentation_105202.png no annotation
# [warning_1] segmentation_105216.png no annotation
# progress:  5200
# [warning_1] segmentation_105229.png no annotation
# [warning_2] segmentation_105240.png skipping the counter
# [warning_1] segmentation_105268.png no annotation
# [warning_1] segmentation_105280.png no annotation
# [warning_1] segmentation_105297.png no annotation
# [warning_1] segmentation_105301.png no annotation
# [warning_1] segmentation_105306.png no annotation
# [warning_1] segmentation_105309.png no annotation
# [warning_1] segmentation_105311.png no annotation
# progress:  5300
# [warning_1] segmentation_105316.png no annotation
# [warning_1] segmentation_105320.png no annotation
# [warning_1] segmentation_105332.png no annotation
# [warning_1] segmentation_10535.png no annotation
# [warning_1] segmentation_105360.png no annotation
# [warning_1] segmentation_105363.png no annotation
# [warning_1] segmentation_105371.png no annotation
# [warning_1] segmentation_105373.png no annotation
# [warning_1] segmentation_105375.png no annotation
# [warning_1] segmentation_105379.png no annotation
# [warning_1] segmentation_105380.png no annotation
# [warning_1] segmentation_105387.png no annotation
# [warning_1] segmentation_105393.png no annotation
# [warning_1] segmentation_105397.png no annotation
# [warning_1] segmentation_10540.png no annotation
# [warning_1] segmentation_105403.png no annotation
# progress:  5400
# [warning_1] segmentation_105420.png no annotation
# [warning_1] segmentation_105422.png no annotation
# [warning_1] segmentation_105427.png no annotation
# [warning_1] segmentation_105432.png no annotation
# [warning_1] segmentation_105450.png no annotation
# [warning_1] segmentation_105453.png no annotation
# [warning_1] segmentation_105485.png no annotation
# [warning_1] segmentation_105495.png no annotation
# [warning_1] segmentation_105498.png no annotation
# [warning_1] segmentation_1055.png no annotation
# [warning_1] segmentation_105506.png no annotation
# [warning_1] segmentation_105508.png no annotation
# [warning_1] segmentation_105517.png no annotation
# [warning_1] segmentation_105519.png no annotation
# [warning_1] segmentation_105522.png no annotation
# progress:  5500
# [warning_1] segmentation_105536.png no annotation
# [warning_1] segmentation_105538.png no annotation
# [warning_1] segmentation_105544.png no annotation
# [warning_1] segmentation_105558.png no annotation
# [warning_1] segmentation_105563.png no annotation
# [warning_1] segmentation_10557.png no annotation
# [warning_1] segmentation_105588.png no annotation
# [warning_1] segmentation_105603.png no annotation
# [warning_1] segmentation_105606.png no annotation
# progress:  5600
# [warning_1] segmentation_105644.png no annotation
# [warning_1] segmentation_105651.png no annotation
# [warning_1] segmentation_10566.png no annotation
# [warning_1] segmentation_105661.png no annotation
# [warning_1] segmentation_105667.png no annotation
# [warning_1] segmentation_105670.png no annotation
# [warning_1] segmentation_105674.png no annotation
# [warning_1] segmentation_105675.png no annotation
# [warning_1] segmentation_105679.png no annotation
# [warning_1] segmentation_1057.png no annotation
# [warning_1] segmentation_105709.png no annotation
# [warning_1] segmentation_105714.png no annotation
# [warning_1] segmentation_105719.png no annotation
# progress:  5700
# [warning_1] segmentation_105733.png no annotation
# [warning_1] segmentation_105737.png no annotation
# [warning_1] segmentation_105780.png no annotation
# [warning_1] segmentation_105787.png no annotation
# [warning_1] segmentation_10579.png no annotation
# [warning_1] segmentation_105790.png no annotation
# [warning_1] segmentation_105798.png no annotation
# [warning_1] segmentation_105804.png no annotation
# [warning_1] segmentation_105813.png no annotation
# progress:  5800
# [warning_1] segmentation_105831.png no annotation
# [warning_1] segmentation_105836.png no annotation
# [warning_1] segmentation_10584.png no annotation
# [warning_1] segmentation_105862.png no annotation
# [warning_1] segmentation_10587.png no annotation
# [warning_1] segmentation_105888.png no annotation
# [warning_1] segmentation_105889.png no annotation
# [warning_1] segmentation_105906.png no annotation
# [warning_1] segmentation_10591.png no annotation
# [warning_1] segmentation_105911.png no annotation
# progress:  5900
# [warning_1] segmentation_105942.png no annotation
# [warning_1] segmentation_105951.png no annotation
# [warning_1] segmentation_105968.png no annotation
# [warning_1] segmentation_105969.png no annotation
# [warning_1] segmentation_105978.png no annotation
# [warning_1] segmentation_105991.png no annotation
# [warning_1] segmentation_105995.png no annotation
# [warning_1] segmentation_1060.png no annotation
# [warning_1] segmentation_106002.png no annotation
# progress:  6000
# [warning_1] segmentation_106025.png no annotation
# [warning_1] segmentation_106027.png no annotation
# [warning_1] segmentation_106028.png no annotation
# [warning_1] segmentation_106029.png no annotation
# [warning_1] segmentation_106035.png no annotation
# [warning_1] segmentation_106036.png no annotation
# [warning_1] segmentation_106043.png no annotation
# [warning_2] segmentation_106051.png skipping the counter
# [warning_1] segmentation_106063.png no annotation
# [warning_1] segmentation_106077.png no annotation
# [warning_1] segmentation_106086.png no annotation
# [warning_1] segmentation_106088.png no annotation
# [warning_1] segmentation_106089.png no annotation
# [warning_1] segmentation_106092.png no annotation
# [warning_1] segmentation_1061.png no annotation
# [warning_1] segmentation_106103.png no annotation
# [warning_1] segmentation_106113.png no annotation
# [warning_1] segmentation_10612.png no annotation
# progress:  6100
# [warning_1] segmentation_106129.png no annotation
# [warning_1] segmentation_10613.png no annotation
# [warning_1] segmentation_106147.png no annotation
# [warning_1] segmentation_106159.png no annotation
# [warning_1] segmentation_10616.png no annotation
# [warning_1] segmentation_106166.png no annotation
# [warning_1] segmentation_106176.png no annotation
# [warning_1] segmentation_10618.png no annotation
# [warning_1] segmentation_106213.png no annotation
# [warning_1] segmentation_106221.png no annotation
# progress:  6200
# [warning_1] segmentation_106231.png no annotation
# [warning_1] segmentation_106234.png no annotation
# [warning_1] segmentation_106237.png no annotation
# [warning_1] segmentation_106239.png no annotation
# [warning_1] segmentation_106245.png no annotation
# [warning_1] segmentation_106252.png no annotation
# [warning_1] segmentation_106275.png no annotation
# [warning_1] segmentation_106276.png no annotation
# [warning_1] segmentation_10630.png no annotation
# [warning_1] segmentation_106302.png no annotation
# [warning_1] segmentation_106309.png no annotation
# progress:  6300
# [warning_1] segmentation_10634.png no annotation
# [warning_1] segmentation_106340.png no annotation
# [warning_1] segmentation_106346.png no annotation
# [warning_1] segmentation_106349.png no annotation
# [warning_2] segmentation_106351.png skipping the counter
# [warning_1] segmentation_106359.png no annotation
# [warning_1] segmentation_106361.png no annotation
# [warning_1] segmentation_106365.png no annotation
# [warning_1] segmentation_106370.png no annotation
# [warning_2] segmentation_106380.png skipping the counter
# [warning_1] segmentation_106382.png no annotation
# [warning_1] segmentation_106388.png no annotation
# [warning_1] segmentation_1064.png no annotation
# [warning_1] segmentation_106407.png no annotation
# [warning_1] segmentation_10641.png no annotation
# [warning_1] segmentation_106410.png no annotation
# [warning_1] segmentation_106415.png no annotation
# [warning_1] segmentation_106420.png no annotation
# progress:  6400
# [warning_1] segmentation_106438.png no annotation
# [warning_1] segmentation_106439.png no annotation
# [warning_1] segmentation_10644.png no annotation
# [warning_1] segmentation_106440.png no annotation
# [warning_1] segmentation_106441.png no annotation
# [warning_1] segmentation_106443.png no annotation
# [warning_1] segmentation_106460.png no annotation
# [warning_1] segmentation_106469.png no annotation
# [warning_1] segmentation_106488.png no annotation
# [warning_1] segmentation_106489.png no annotation
# [warning_1] segmentation_106490.png no annotation
# [warning_1] segmentation_106492.png no annotation
# [warning_1] segmentation_106495.png no annotation
# [warning_1] segmentation_106498.png no annotation
# [warning_1] segmentation_106507.png no annotation
# [warning_1] segmentation_106521.png no annotation
# [warning_1] segmentation_106531.png no annotation
# progress:  6500
# [warning_1] segmentation_106547.png no annotation
# [warning_1] segmentation_106552.png no annotation
# [warning_1] segmentation_106556.png no annotation
# [warning_1] segmentation_106565.png no annotation
# [warning_1] segmentation_106567.png no annotation
# [warning_1] segmentation_106574.png no annotation
# [warning_1] segmentation_106583.png no annotation
# [warning_2] segmentation_10660.png skipping the counter
# [warning_1] segmentation_106604.png no annotation
# [warning_1] segmentation_106619.png no annotation
# progress:  6600
# [warning_1] segmentation_106638.png no annotation
# [warning_1] segmentation_106649.png no annotation
# [warning_1] segmentation_106653.png no annotation
# [warning_1] segmentation_106665.png no annotation
# [warning_1] segmentation_10667.png no annotation
# [warning_1] segmentation_106676.png no annotation
# [warning_1] segmentation_106679.png no annotation
# [warning_1] segmentation_106682.png no annotation
# [warning_1] segmentation_106703.png no annotation
# [warning_1] segmentation_106709.png no annotation
# [warning_2] segmentation_106717.png skipping the counter
# [warning_1] segmentation_106721.png no annotation
# progress:  6700
# [warning_1] segmentation_106732.png no annotation
# [warning_1] segmentation_106742.png no annotation
# [warning_1] segmentation_106747.png no annotation
# [warning_1] segmentation_106757.png no annotation
# [warning_1] segmentation_106791.png no annotation
# [warning_1] segmentation_1068.png no annotation
# [warning_1] segmentation_106801.png no annotation
# [warning_2] segmentation_106807.png skipping the counter
# [warning_1] segmentation_106812.png no annotation
# [warning_1] segmentation_106813.png no annotation
# [warning_1] segmentation_106814.png no annotation
# [warning_1] segmentation_106816.png no annotation
# progress:  6800
# [warning_1] segmentation_106832.png no annotation
# [warning_1] segmentation_106844.png no annotation
# [warning_1] segmentation_106848.png no annotation
# [warning_2] segmentation_106857.png skipping the counter
# [warning_1] segmentation_106866.png no annotation
# [warning_1] segmentation_106870.png no annotation
# [warning_2] segmentation_106887.png skipping the counter
# [warning_1] segmentation_106898.png no annotation
# progress:  6900
# [warning_1] segmentation_106927.png no annotation
# [warning_1] segmentation_10693.png no annotation
# [warning_1] segmentation_106931.png no annotation
# [warning_1] segmentation_106940.png no annotation
# [warning_1] segmentation_106941.png no annotation
# [warning_1] segmentation_106943.png no annotation
# [warning_1] segmentation_106948.png no annotation
# [warning_1] segmentation_10695.png no annotation
# [warning_1] segmentation_106956.png no annotation
# [warning_1] segmentation_106958.png no annotation
# [warning_1] segmentation_106960.png no annotation
# [warning_1] segmentation_106983.png no annotation
# [warning_1] segmentation_106992.png no annotation
# [warning_1] segmentation_107012.png no annotation
# progress:  7000
# [warning_1] segmentation_107039.png no annotation
# [warning_1] segmentation_107043.png no annotation
# [warning_1] segmentation_107051.png no annotation
# [warning_1] segmentation_107054.png no annotation
# [warning_1] segmentation_107055.png no annotation
# [warning_1] segmentation_107056.png no annotation
# [warning_1] segmentation_107059.png no annotation
# [warning_1] segmentation_107063.png no annotation
# [warning_1] segmentation_107071.png no annotation
# [warning_1] segmentation_107077.png no annotation
# [warning_1] segmentation_107080.png no annotation
# [warning_1] segmentation_107084.png no annotation
# [warning_1] segmentation_10709.png no annotation
# [warning_1] segmentation_107092.png no annotation
# [warning_1] segmentation_107095.png no annotation
# [warning_1] segmentation_107104.png no annotation
# [warning_1] segmentation_107105.png no annotation
# [warning_1] segmentation_107111.png no annotation
# [warning_1] segmentation_107113.png no annotation
# [warning_1] segmentation_107119.png no annotation
# [warning_1] segmentation_107134.png no annotation
# progress:  7100
# [warning_1] segmentation_107151.png no annotation
# [warning_1] segmentation_107157.png no annotation
# [warning_1] segmentation_107172.png no annotation
# [warning_1] segmentation_10720.png no annotation
# [warning_1] segmentation_107204.png no annotation
# [warning_1] segmentation_107205.png no annotation
# [warning_1] segmentation_107208.png no annotation
# [warning_1] segmentation_107226.png no annotation
# [warning_1] segmentation_10723.png no annotation
# progress:  7200
# [warning_1] segmentation_107237.png no annotation
# [warning_1] segmentation_10724.png no annotation
# [warning_1] segmentation_107243.png no annotation
# [warning_1] segmentation_107276.png no annotation
# [warning_2] segmentation_107284.png skipping the counter
# [warning_1] segmentation_107286.png no annotation
# [warning_1] segmentation_107295.png no annotation
# [warning_1] segmentation_107296.png no annotation
# [warning_1] segmentation_107312.png no annotation
# [warning_1] segmentation_107318.png no annotation
# [warning_1] segmentation_107326.png no annotation
# progress:  7300
# [warning_1] segmentation_107336.png no annotation
# [warning_1] segmentation_10735.png no annotation
# [warning_1] segmentation_107359.png no annotation
# [warning_1] segmentation_107387.png no annotation
# [warning_1] segmentation_10739.png no annotation
# [warning_1] segmentation_107393.png no annotation
# [warning_1] segmentation_107395.png no annotation
# [warning_1] segmentation_107399.png no annotation
# [warning_1] segmentation_107403.png no annotation
# [warning_1] segmentation_107415.png no annotation
# [warning_1] segmentation_107431.png no annotation
# [warning_1] segmentation_107432.png no annotation
# progress:  7400
# [warning_1] segmentation_107441.png no annotation
# [warning_1] segmentation_107443.png no annotation
# [warning_1] segmentation_107451.png no annotation
# [warning_1] segmentation_107474.png no annotation
# [warning_1] segmentation_107475.png no annotation
# [warning_1] segmentation_107477.png no annotation
# [warning_1] segmentation_107488.png no annotation
# [warning_1] segmentation_107499.png no annotation
# [warning_1] segmentation_107501.png no annotation
# [warning_1] segmentation_107505.png no annotation
# [warning_1] segmentation_107515.png no annotation
# [warning_2] segmentation_107524.png skipping the counter
# [warning_1] segmentation_10753.png no annotation
# [warning_1] segmentation_107530.png no annotation
# [warning_1] segmentation_107532.png no annotation
# progress:  7500
# [warning_1] segmentation_107541.png no annotation
# [warning_1] segmentation_107566.png no annotation
# [warning_1] segmentation_107574.png no annotation
# [warning_1] segmentation_107579.png no annotation
# [warning_1] segmentation_107588.png no annotation
# [warning_1] segmentation_107595.png no annotation
# [warning_1] segmentation_107607.png no annotation
# [warning_1] segmentation_107610.png no annotation
# [warning_1] segmentation_107613.png no annotation
# [warning_1] segmentation_107617.png no annotation
# [warning_1] segmentation_107625.png no annotation
# progress:  7600
# [warning_1] segmentation_107640.png no annotation
# [warning_1] segmentation_107646.png no annotation
# [warning_1] segmentation_107649.png no annotation
# [warning_1] segmentation_107650.png no annotation
# [warning_1] segmentation_107656.png no annotation
# [warning_1] segmentation_107661.png no annotation
# [warning_1] segmentation_107662.png no annotation
# [warning_1] segmentation_107664.png no annotation
# [warning_2] segmentation_107669.png skipping the counter
# [warning_1] segmentation_107678.png no annotation
# [warning_1] segmentation_107682.png no annotation
# [warning_1] segmentation_107684.png no annotation
# [warning_1] segmentation_107690.png no annotation
# [warning_1] segmentation_107695.png no annotation
# [warning_1] segmentation_1077.png no annotation
# [warning_1] segmentation_107700.png no annotation
# [warning_1] segmentation_107701.png no annotation
# ...
# [warning_1] segmentation_97286.png no annotation
# [warning_1] segmentation_97308.png no annotation
# progress:  266800
# [warning_1] segmentation_97320.png no annotation
# [warning_1] segmentation_97333.png no annotation
# [warning_1] segmentation_97344.png no annotation
# [warning_1] segmentation_97345.png no annotation
# [warning_1] segmentation_9735.png no annotation
# [warning_1] segmentation_97363.png no annotation
# [warning_1] segmentation_97368.png no annotation
# [warning_1] segmentation_9737.png no annotation
# [warning_1] segmentation_97370.png no annotation
# [warning_1] segmentation_97377.png no annotation
# [warning_1] segmentation_97384.png no annotation
# [warning_1] segmentation_97385.png no annotation
# [warning_1] segmentation_97388.png no annotation
# [warning_1] segmentation_97399.png no annotation
# [warning_1] segmentation_9740.png no annotation
# [warning_1] segmentation_97408.png no annotation
# progress:  266900
# [warning_1] segmentation_97427.png no annotation
# [warning_1] segmentation_9743.png no annotation
# [warning_1] segmentation_97437.png no annotation
# [warning_1] segmentation_97449.png no annotation
# [warning_1] segmentation_97451.png no annotation
# [warning_1] segmentation_97456.png no annotation
# [warning_1] segmentation_9746.png no annotation
# [warning_1] segmentation_97476.png no annotation
# [warning_1] segmentation_97483.png no annotation
# [warning_1] segmentation_97493.png no annotation
# [warning_1] segmentation_97500.png no annotation
# [warning_1] segmentation_97501.png no annotation
# [warning_1] segmentation_97503.png no annotation
# [warning_1] segmentation_97521.png no annotation
# progress:  267000
# [warning_1] segmentation_97529.png no annotation
# [warning_1] segmentation_97537.png no annotation
# [warning_1] segmentation_97547.png no annotation
# [warning_1] segmentation_97576.png no annotation
# [warning_1] segmentation_97580.png no annotation
# [warning_1] segmentation_97583.png no annotation
# [warning_1] segmentation_97585.png no annotation
# [warning_1] segmentation_97588.png no annotation
# [warning_1] segmentation_97601.png no annotation
# [warning_1] segmentation_97610.png no annotation
# [warning_1] segmentation_97617.png no annotation
# [warning_1] segmentation_97624.png no annotation
# progress:  267100
# [warning_2] segmentation_97639.png skipping the counter
# [warning_1] segmentation_97643.png no annotation
# [warning_1] segmentation_97653.png no annotation
# [warning_1] segmentation_97655.png no annotation
# [warning_2] segmentation_97673.png skipping the counter
# [warning_1] segmentation_97674.png no annotation
# [warning_1] segmentation_97699.png no annotation
# [warning_1] segmentation_97706.png no annotation
# [warning_1] segmentation_97712.png no annotation
# [warning_1] segmentation_97714.png no annotation
# progress:  267200
# [warning_1] segmentation_97768.png no annotation
# [warning_1] segmentation_97771.png no annotation
# [warning_1] segmentation_97794.png no annotation
# [warning_1] segmentation_97795.png no annotation
# [warning_1] segmentation_97807.png no annotation
# [warning_1] segmentation_97815.png no annotation
# progress:  267300
# [warning_1] segmentation_97832.png no annotation
# [warning_1] segmentation_97837.png no annotation
# [warning_1] segmentation_97838.png no annotation
# [warning_1] segmentation_97849.png no annotation
# [warning_1] segmentation_97851.png no annotation
# [warning_1] segmentation_97859.png no annotation
# [warning_1] segmentation_97870.png no annotation
# [warning_1] segmentation_97871.png no annotation
# [warning_1] segmentation_97885.png no annotation
# [warning_1] segmentation_97886.png no annotation
# [warning_1] segmentation_97898.png no annotation
# progress:  267400
# [warning_1] segmentation_97919.png no annotation
# [warning_1] segmentation_97920.png no annotation
# [warning_1] segmentation_97921.png no annotation
# [warning_1] segmentation_97929.png no annotation
# [warning_1] segmentation_97933.png no annotation
# [warning_1] segmentation_97948.png no annotation
# [warning_1] segmentation_97949.png no annotation
# [warning_1] segmentation_97964.png no annotation
# [warning_1] segmentation_97968.png no annotation
# [warning_1] segmentation_97969.png no annotation
# [warning_1] segmentation_97977.png no annotation
# [warning_1] segmentation_9798.png no annotation
# [warning_1] segmentation_97989.png no annotation
# [warning_1] segmentation_97990.png no annotation
# [warning_1] segmentation_98005.png no annotation
# [warning_1] segmentation_98019.png no annotation
# progress:  267500
# [warning_1] segmentation_98052.png no annotation
# [warning_1] segmentation_98081.png no annotation
# [warning_1] segmentation_98083.png no annotation
# [warning_1] segmentation_98087.png no annotation
# [warning_1] segmentation_98090.png no annotation
# [warning_1] segmentation_98091.png no annotation
# [warning_1] segmentation_98093.png no annotation
# [warning_1] segmentation_98101.png no annotation
# [warning_1] segmentation_98114.png no annotation
# progress:  267600
# [warning_1] segmentation_9813.png no annotation
# [warning_1] segmentation_98131.png no annotation
# [warning_1] segmentation_98135.png no annotation
# [warning_1] segmentation_98139.png no annotation
# [warning_1] segmentation_98140.png no annotation
# [warning_1] segmentation_98151.png no annotation
# [warning_1] segmentation_9816.png no annotation
# [warning_1] segmentation_98164.png no annotation
# [warning_1] segmentation_98169.png no annotation
# [warning_1] segmentation_98171.png no annotation
# [warning_1] segmentation_98172.png no annotation
# [warning_1] segmentation_98176.png no annotation
# [warning_1] segmentation_98182.png no annotation
# [warning_1] segmentation_98184.png no annotation
# [warning_1] segmentation_98185.png no annotation
# [warning_1] segmentation_98192.png no annotation
# [warning_1] segmentation_98209.png no annotation
# [warning_1] segmentation_98212.png no annotation
# [warning_1] segmentation_98223.png no annotation
# progress:  267700
# [warning_1] segmentation_98235.png no annotation
# [warning_1] segmentation_98245.png no annotation
# [warning_1] segmentation_98254.png no annotation
# [warning_1] segmentation_98266.png no annotation
# [warning_1] segmentation_98267.png no annotation
# [warning_1] segmentation_98275.png no annotation
# [warning_1] segmentation_98308.png no annotation
# [warning_1] segmentation_98311.png no annotation
# progress:  267800
# [warning_1] segmentation_98331.png no annotation
# [warning_1] segmentation_98341.png no annotation
# [warning_1] segmentation_98346.png no annotation
# [warning_1] segmentation_98351.png no annotation
# [warning_1] segmentation_98353.png no annotation
# [warning_1] segmentation_98361.png no annotation
# [warning_1] segmentation_98370.png no annotation
# [warning_1] segmentation_98380.png no annotation
# [warning_1] segmentation_98381.png no annotation
# [warning_1] segmentation_98395.png no annotation
# [warning_1] segmentation_98413.png no annotation
# [warning_1] segmentation_98415.png no annotation
# progress:  267900
# [warning_2] segmentation_98426.png skipping the counter
# [warning_1] segmentation_98444.png no annotation
# [warning_1] segmentation_98447.png no annotation
# [warning_1] segmentation_98455.png no annotation
# [warning_1] segmentation_98463.png no annotation
# [warning_1] segmentation_98487.png no annotation
# [warning_1] segmentation_9849.png no annotation
# [warning_1] segmentation_98491.png no annotation
# [warning_1] segmentation_98492.png no annotation
# [warning_1] segmentation_98497.png no annotation
# [warning_1] segmentation_98513.png no annotation
# progress:  268000
# [warning_1] segmentation_98542.png no annotation
# [warning_1] segmentation_98551.png no annotation
# [warning_1] segmentation_98560.png no annotation
# [warning_1] segmentation_98595.png no annotation
# [warning_1] segmentation_98607.png no annotation
# [warning_1] segmentation_98609.png no annotation
# progress:  268100
# [warning_1] segmentation_98635.png no annotation
# [warning_1] segmentation_98656.png no annotation
# [warning_1] segmentation_98661.png no annotation
# [warning_1] segmentation_98674.png no annotation
# [warning_1] segmentation_98677.png no annotation
# [warning_1] segmentation_98683.png no annotation
# [warning_1] segmentation_98684.png no annotation
# [warning_1] segmentation_98685.png no annotation
# [warning_1] segmentation_98692.png no annotation
# [warning_1] segmentation_98693.png no annotation
# [warning_1] segmentation_98702.png no annotation
# progress:  268200
# [warning_1] segmentation_98731.png no annotation
# [warning_1] segmentation_9875.png no annotation
# [warning_1] segmentation_98767.png no annotation
# [warning_1] segmentation_9878.png no annotation
# [warning_1] segmentation_988.png no annotation
# [warning_1] segmentation_9881.png no annotation
# [warning_1] segmentation_98813.png no annotation
# progress:  268300
# [warning_1] segmentation_98817.png no annotation
# [warning_1] segmentation_98833.png no annotation
# [warning_2] segmentation_98841.png skipping the counter
# [warning_1] segmentation_98862.png no annotation
# [warning_1] segmentation_98873.png no annotation
# [warning_1] segmentation_9888.png no annotation
# [warning_1] segmentation_98880.png no annotation
# [warning_1] segmentation_98882.png no annotation
# [warning_1] segmentation_98903.png no annotation
# [warning_1] segmentation_98906.png no annotation
# [warning_1] segmentation_98913.png no annotation
# progress:  268400
# [warning_1] segmentation_98916.png no annotation
# [warning_1] segmentation_98929.png no annotation
# [warning_1] segmentation_98933.png no annotation
# [warning_1] segmentation_98939.png no annotation
# [warning_1] segmentation_98948.png no annotation
# [warning_1] segmentation_98949.png no annotation
# [warning_1] segmentation_98978.png no annotation
# [warning_1] segmentation_98994.png no annotation
# [warning_1] segmentation_98995.png no annotation
# [warning_1] segmentation_98999.png no annotation
# [warning_1] segmentation_99005.png no annotation
# [warning_1] segmentation_99007.png no annotation
# progress:  268500
# [warning_1] segmentation_99022.png no annotation
# [warning_1] segmentation_99024.png no annotation
# [warning_1] segmentation_99025.png no annotation
# [warning_1] segmentation_99032.png no annotation
# [warning_1] segmentation_99036.png no annotation
# [warning_1] segmentation_99040.png no annotation
# [warning_1] segmentation_99050.png no annotation
# [warning_1] segmentation_99055.png no annotation
# [warning_1] segmentation_99059.png no annotation
# [warning_1] segmentation_99064.png no annotation
# [warning_1] segmentation_99073.png no annotation
# [warning_1] segmentation_99079.png no annotation
# [warning_1] segmentation_99087.png no annotation
# [warning_1] segmentation_99088.png no annotation
# [warning_1] segmentation_99092.png no annotation
# [warning_1] segmentation_99095.png no annotation
# [warning_1] segmentation_99100.png no annotation
# [warning_1] segmentation_99104.png no annotation
# [warning_1] segmentation_99112.png no annotation
# [warning_1] segmentation_99114.png no annotation
# [warning_1] segmentation_99117.png no annotation
# [warning_1] segmentation_99124.png no annotation
# progress:  268600
# [warning_1] segmentation_99126.png no annotation
# [warning_1] segmentation_99134.png no annotation
# [warning_1] segmentation_99139.png no annotation
# [warning_1] segmentation_99152.png no annotation
# [warning_1] segmentation_9916.png no annotation
# [warning_1] segmentation_99160.png no annotation
# [warning_1] segmentation_99185.png no annotation
# [warning_1] segmentation_9919.png no annotation
# [warning_2] segmentation_99197.png skipping the counter
# [warning_1] segmentation_992.png no annotation
# [warning_1] segmentation_9921.png no annotation
# [warning_1] segmentation_99219.png no annotation
# [warning_1] segmentation_99224.png no annotation
# progress:  268700
# [warning_2] segmentation_99234.png skipping the counter
# [warning_1] segmentation_99238.png no annotation
# [warning_1] segmentation_99256.png no annotation
# [warning_2] segmentation_99261.png skipping the counter
# [warning_1] segmentation_99302.png no annotation
# [warning_1] segmentation_99318.png no annotation
# progress:  268800
# [warning_1] segmentation_99336.png no annotation
# [warning_1] segmentation_99342.png no annotation
# [warning_1] segmentation_99375.png no annotation
# [warning_1] segmentation_99381.png no annotation
# [warning_1] segmentation_99396.png no annotation
# [warning_1] segmentation_99399.png no annotation
# [warning_1] segmentation_99402.png no annotation
# progress:  268900
# [warning_1] segmentation_99423.png no annotation
# [warning_1] segmentation_9943.png no annotation
# [warning_1] segmentation_99430.png no annotation
# [warning_1] segmentation_99435.png no annotation
# [warning_1] segmentation_9944.png no annotation
# [warning_1] segmentation_99447.png no annotation
# [warning_1] segmentation_99457.png no annotation
# [warning_1] segmentation_99462.png no annotation
# [warning_1] segmentation_99466.png no annotation
# [warning_1] segmentation_99468.png no annotation
# [warning_1] segmentation_99474.png no annotation
# [warning_1] segmentation_99478.png no annotation
# [warning_1] segmentation_9950.png no annotation
# progress:  269000
# [warning_1] segmentation_99519.png no annotation
# [warning_1] segmentation_99544.png no annotation
# [warning_1] segmentation_99547.png no annotation
# [warning_1] segmentation_99562.png no annotation
# [warning_1] segmentation_99576.png no annotation
# [warning_1] segmentation_99584.png no annotation
# [warning_1] segmentation_99585.png no annotation
# [warning_1] segmentation_99593.png no annotation
# [warning_1] segmentation_99612.png no annotation
# progress:  269100
# [warning_1] segmentation_99625.png no annotation
# [warning_1] segmentation_99631.png no annotation
# [warning_1] segmentation_99637.png no annotation
# [warning_1] segmentation_99643.png no annotation
# [warning_1] segmentation_99651.png no annotation
# [warning_1] segmentation_9966.png no annotation
# [warning_1] segmentation_99680.png no annotation
# [warning_1] segmentation_99684.png no annotation
# [warning_1] segmentation_99685.png no annotation
# [warning_1] segmentation_99691.png no annotation
# [warning_1] segmentation_99703.png no annotation
# [warning_1] segmentation_99716.png no annotation
# progress:  269200
# [warning_2] segmentation_9972.png skipping the counter
# [warning_1] segmentation_99727.png no annotation
# [warning_1] segmentation_99729.png no annotation
# [warning_1] segmentation_99731.png no annotation
# [warning_1] segmentation_99753.png no annotation
# [warning_1] segmentation_99754.png no annotation
# [warning_1] segmentation_99758.png no annotation
# [warning_1] segmentation_99768.png no annotation
# [warning_1] segmentation_99773.png no annotation
# [warning_1] segmentation_99780.png no annotation
# [warning_1] segmentation_99781.png no annotation
# [warning_1] segmentation_99793.png no annotation
# [warning_1] segmentation_99809.png no annotation
# progress:  269300
# [warning_1] segmentation_9982.png no annotation
# [warning_1] segmentation_99828.png no annotation
# [warning_1] segmentation_99843.png no annotation
# [warning_1] segmentation_99845.png no annotation
# [warning_1] segmentation_9986.png no annotation
# [warning_1] segmentation_99872.png no annotation
# [warning_1] segmentation_99877.png no annotation
# [warning_1] segmentation_99881.png no annotation
# [warning_1] segmentation_99885.png no annotation
# [warning_1] segmentation_99895.png no annotation
# [warning_1] segmentation_99896.png no annotation
# [warning_1] segmentation_99899.png no annotation
# [warning_1] segmentation_99908.png no annotation
# [warning_1] segmentation_99911.png no annotation
# [warning_1] segmentation_99918.png no annotation
# progress:  269400
# [warning_1] segmentation_99925.png no annotation
# [warning_1] segmentation_99929.png no annotation
# [warning_1] segmentation_9993.png no annotation
# [warning_1] segmentation_99932.png no annotation
# [warning_1] segmentation_99936.png no annotation
# [warning_1] segmentation_99943.png no annotation
# [warning_1] segmentation_99961.png no annotation
# [warning_1] segmentation_99973.png no annotation
# [warning_1] segmentation_99982.png no annotation
# [warning_1] segmentation_99984.png no annotation
# 299999 個のファイルのうち 30524 個はクレータが存在しないため無視しました
# 最終的なデータ数は 269475 です
# ===== create annotation complete!! =====
# finish

# %% [markdown]
# # json書き込み
# - 一回だけだと書き込めないバグがあるので，二回実行する

# %%
# write
# 書き出すjsonのファイル名
json_name = base_path + "valid_moon.json"

fw = open(json_name, 'w')
json.dump(js, fw)
# json.dump(js, fw, indent=2)

# %% [markdown]
# # テスト用
# - 書き込みが成功していれば，categoriesを確認することができる
# - errorが出れば，書き込みに失敗しているので，書き込みをもう一回実行する

# %%
with open(json_name) as f:
    df = json.load(f)
# print(len(df["images"]))
print("last_image_id =", df["images"][-1]["id"])
print("info = ", df["info"])

# %%
# with open("train_moon.json") as f:
#     df = json.load(f)
print(df["annotations"][13]["segmentation"])

# %% [markdown]
# # 必要なし

# %%
tmp = ""
tmp = info()
js[0] = tmp
print(js[0])

# %%
# plant_book_mask_image = Image.open('/home/yuga/.config/unity3d/DefaultCompany/PerceptionURP/train/semas/segmentation_2.png').convert('RGB')
# bottle_book_mask_image = Image.open('/home/yuga/.config/unity3d/DefaultCompany/PerceptionURP/train/semas/segmentation_3.png').convert('RGB')

plant_book_mask_image = Image.open('images/plant_book_mask.png')
bottle_book_mask_image = Image.open('images/bottle_book_mask.png')

mask_images = [plant_book_mask_image, bottle_book_mask_image]

# Define which colors match which categories in the images
houseplant_id, book_id, bottle_id, lamp_id = [1, 2, 3, 4]
category_ids = {
    1: {
        '(0, 255, 0)': houseplant_id,
        '(0, 0, 255)': book_id,
    },
    2: {
        '(255, 255, 0)': bottle_id,
        '(255, 0, 128)': book_id,
        '(255, 100, 0)': lamp_id,
    }
}

is_crowd = 0

# These ids will be automatically increased as we go
annotation_id = 1
image_id = 1

# Create the annotations
annotations = []
for mask_image in mask_images:
    print(mask_image)
    sub_masks = create_sub_masks(mask_image)
    for color, sub_mask in sub_masks.items():
        category_id = category_ids[image_id][color]
        print(sub_mask)
        plt.imshow(sub_mask)
        plt.show(sub_mask)
        annotation = create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd)
        annotations.append(annotation)
        annotation_id += 1
    image_id += 1

print(json.dumps(annotations))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage import measure
from skimage.segmentation import clear_border
from skimage.filters import threshold_otsu
plt.rcParams['font.size']=12
plt.rcParams['font.family'] = 'sans-serif'

#make data
n = 6
s = 256
im = np.zeros((s, s))
points = (s*np.random.random((2, n**2))).astype(int)
im[points[0], points[1]] = 1
im = ndimage.gaussian_filter(im, sigma=s/(5.*n))

thresh = threshold_otsu(im)
im = im > thresh 
im = clear_border(im)

print(im)
contours = measure.find_contours(im, 0.5)

fig, ax = plt.subplots(figsize=(6,6))
for n, contour in enumerate(contours):
    ax.plot(contour[:, 1], contour[:, 0], linewidth=4)
    ax.text(contour[0, 1], contour[0, 0],n)
    
ax.imshow(im, cmap=plt.cm.cividis, interpolation='gaussian',origin='lower',alpha=0.5)
plt.savefig('findcontours05.png',dpi=100)
plt.show()

# %%
def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
    contours = measure.find_contours(sub_mask, 0.5)

    segmentations = []
    polygons = []
    for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
        for i in range(len(contour)):
            row, col = contour[i]
            contour[i] = (col - 1, row - 1)

        # Make a polygon and simplify it
        poly = Polygon(contour)
        poly = poly.simplify(1.0, preserve_topology=False)
        polygons.append(poly)
        segmentation = np.array(poly.exterior.coords).ravel().tolist()
        segmentations.append(segmentation)

    # Combine the polygons to calculate the bounding box and area
    multi_poly = MultiPolygon(polygons)
    x, y, max_x, max_y = multi_poly.bounds
    width = max_x - x
    height = max_y - y
    bbox = (x, y, width, height)
    area = multi_poly.area

    annotation = {
        'segmentation': segmentations,
        'iscrowd': is_crowd,
        'image_id': image_id,
        'category_id': category_id,
        'id': annotation_id,
        'bbox': bbox,
        'area': area
    }

    return annotation

# %%
def create_sub_masks(mask_image):
    width, height = mask_image.size

    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            pixel = mask_image.getpixel((x,y))[:3]

            # If the pixel is not black...
            if pixel != (0, 0, 0):
                # Check to see if we've created a sub-mask...
                pixel_str = str(pixel)
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks
