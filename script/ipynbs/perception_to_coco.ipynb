# %%
# json/coco utils for Unity
# lessw2020
# https://github.com/lessw2020/perception_tools

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path, PurePath
Path.cwd()
# Out:
# PosixPath('/home/yuga/yolact_ws/perception_tools')

# %%
import json
from copy import deepcopy
import os
from datetime import datetime as dt

# %% [markdown]
# ## functions

# %%
def require_dir(item, type="Dataset"):
    itemp = Path(item)
    if not itemp.is_dir():
        raise ValueError(f"directory of type {type} not found. aborting...")

def get_sub_folders(upper_path):
    # verify upper path
    fpath = Path(upper_path)
    
    require_dir(fpath, "Perception root dir")  # will break with raise error if not dir
    
    # get required subfolders
    # dataset
    #subdirs = [f.path for f in os.scandir(upper_path) if f.is_dir() ]
    
    dataset_glob = fpath.glob("Dataset*")
    try:
        dataset_dir = next(dataset_glob) 
    except StopIteration:
        print(f"** failed to get Dataset dir. aborting..")
        return None, None
    
    require_dir(dataset_dir, "Dataset")
    
    print(f"--> using {dataset_dir.name} to generate annotations")
    
    image_glob = fpath.glob("RGB*")
    
    try:
        image_dir = next(image_glob)
    except StopIteration:
        print(f"** failed to get an image dir. aborting...")
        return None, None
        
    
    print(f"--> using {image_dir.name} for images")
    
    
        
    
        
    return image_dir, dataset_dir

# %%
def get_anno_file(dataset_dir):
    anno_file = dataset_dir/'annotation_definitions.json'
    return anno_file

# %%
def open_json(fpath):
    try:
        with open(str(fpath)) as f:
            jh = json.load(f)
    except:
        raise ValueError(f"failed to open {fpath} for read")
    return jh

# %%
def get_perception_categories(anno_file, show_info=True, supercategory = "rdt"):
    
    fh = open_json(anno_file)
    anno_list = fh['annotation_definitions']
    spec = anno_list[0]
    spec = spec['spec']
    print(f"\n--> labels in perception definitions:\n")
    for item in spec:
        print(item)
    
    print(f"\n-->building coco categories:")
    coco_category_block = []
    for item in spec:
        holding = {}
        holding['id']= item['label_id']
        
        holding['name'] = item['label_name']
        holding['supercategory']=supercategory
        print(holding)
        coco_category_block.append(holding)
    return coco_category_block

# %%
def get_perception_annotations(anno_dir, image_width=1024, image_height=768):
    
    anno_id = 0  # can also start with 1 if desired
    image_id = 0
    
    images_block = []
    annos_block = []
    
    capture_files = anno_dir.glob('captures*.json')
    
    for j,_ in enumerate(capture_files):
        pass
    
    print(f"\n--> {j+1} capture files detected. Processing...")
    
    # processing
    capture_files = anno_dir.glob('captures*.json')
    print(capture_files)
    
    for item in capture_files:
    
        fh = open_json(item)
        
        captures = fh['captures']
        
        for image_entry in captures:
            image_dict = {}
            
            image_dict['id'] = image_id
            
            fp = Path(image_entry['filename'])
            
            # it's likely you are exporting all images as same size.
            # could open each image and check height/width, but will use passed in args for now
            image_dict['width'] = image_width
            image_dict['height'] = image_height
            image_dict['file_name'] = fp.name
            
            # dummy values 
            image_dict['license'] = None
            image_dict['flickr_url'] = ""
            image_dict['coco_url'] = ""
            image_dict['date_captured'] = "0:00"
            
            images_block.append(deepcopy(image_dict))
            
            annos = image_entry['annotations']
            
            ad = {}
            
            for a in annos:
                ad.update(a)
            
            values = ad['values']
                
            coco_anno = []
            
            for item in values:
                temp_anno={}
#                 x = item['x']
#                 y = item['y']
#                 w = item['width']
#                 h = item['height']
                
#                 bbox = [x,y,w,h]
                
                temp_anno["id"] = anno_id
#                 temp_anno["image_id"] = image_id
#                 temp_anno["category_id"] = item["label_id"]
                
                #bbox details
#                 temp_anno["bbox"] = bbox
#                 temp_anno["area"] = int(w*h)
                
                #segmentation - todo if needed
                temp_anno["segmentation"] = 
                temp_anno["iscrowd"] = 0
                # ADDME
                temp_anno["image_id"] = anno_id
                temp_anno["category_id"] = 1
                
                annos_block.append(deepcopy(temp_anno))

                anno_id +=1
            
            image_id+=1
        
    print(f"--> annotation processing completed.")
    return images_block, annos_block

# %%
def convert_perception(base_dir, out_file="coco_labels.json", image_width=1024, image_height=768):
    """ 
    main entry for converting perception output into ready to train coco file
    
    note - currently image height and width are passed in /hardcoded.  Workaround is can open every image file
    and check, or update perception to export image info...for now just using passed in vars
    
    """
    
    image_dir, dataset_dir = get_sub_folders(base_dir)
    print(dataset_dir)
    
    mainfile = {}
    
    #build info section
    infod = {}
    
    today = dt.today()
    infod['year'] = str(today.year)
    infod['date_created'] = str(today)

    infod['version']= "1.0"
    infod['contributor']="lessw2020"
    infod['url']='https://github.com/lessw2020/perception_tools'
    
    mainfile['info'] = infod
    
    mainfile['licenses'] = []
    
    # get categories
    perception_anno = get_anno_file(dataset_dir)
    
    coco_cats = get_perception_categories(perception_anno)
    
    mainfile['categories'] = coco_cats
    
    #print(f"--> mainfile = {mainfile}")
    
    # get annotations
    images_block, annos_block = get_perception_annotations(dataset_dir, 
                                                           image_width, image_height)
    
    mainfile['images'] = images_block
    mainfile['annotations'] = annos_block
    
    if out_file:
        save_file = dataset_dir/out_file
        with open(save_file,'w') as fh:
            json.dump(mainfile, fh)
    
    # all done
    print(f"\n--> Processing complete.  Total images = {len(mainfile['images'])}\n")
    
    return mainfile

# %% [markdown]
# ## begin processing here (ensure all cells above have been run...)

# %%
perception_folder = "/home/yuga/.config/unity3d/DefaultCompany/PerceptionURP/c02420e7-74a4-496c-b91b-5e4901f8b7ca/"

# %%
z = convert_perception(perception_folder, image_width=1280, image_height=720)  # add out_name to customize, image_width and image_height
# Out:
# --> using Dataset6f2b264e-a71f-4c26-a88f-5da88af86519 to generate annotations
# --> using RGB17f81d0f-4700-4ccf-939b-47dabade636c for images
# /home/yuga/.config/unity3d/DefaultCompany/PerceptionURP/c02420e7-74a4-496c-b91b-5e4901f8b7ca/Dataset6f2b264e-a71f-4c26-a88f-5da88af86519
#
# --> labels in perception definitions:
#
# {'label_id': 1, 'label_name': 'crater'}
#
# -->building coco categories:
# {'id': 1, 'name': 'crater', 'supercategory': 'rdt'}
#
# --> 1 capture files detected. Processing...
# <generator object Path.glob at 0x7fc5f46c7b50>
# --> annotation processing completed.
#
# --> Processing complete.  Total images = 99

# %%
z
# Out:
# {'info': {'year': '2021',
#   'date_created': '2021-09-24 23:07:56.012222',
#   'version': '1.0',
#   'contributor': 'lessw2020',
#   'url': 'https://github.com/lessw2020/perception_tools'},
#  'licenses': [],
#  'categories': [{'id': 1, 'name': 'crater', 'supercategory': 'rdt'}],
#  'images': [{'id': 0,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_2.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 1,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_3.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 2,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_4.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 3,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_5.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 4,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_6.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 5,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_7.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 6,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_8.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 7,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_9.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 8,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_10.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 9,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_11.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 10,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_12.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 11,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_13.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 12,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_14.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 13,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_15.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 14,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_16.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 15,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_17.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 16,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_18.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 17,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_19.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 18,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_20.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 19,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_21.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 20,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_22.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 21,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_23.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 22,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_24.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 23,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_25.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 24,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_26.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 25,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_27.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 26,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_28.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 27,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_29.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 28,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_30.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 29,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_31.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 30,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_32.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 31,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_33.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 32,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_34.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 33,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_35.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 34,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_36.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 35,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_37.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 36,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_38.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 37,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_39.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 38,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_40.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 39,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_41.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 40,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_42.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 41,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_43.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 42,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_44.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 43,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_45.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 44,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_46.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 45,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_47.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 46,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_48.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 47,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_49.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 48,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_50.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 49,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_51.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 50,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_52.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 51,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_53.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 52,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_54.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 53,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_55.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 54,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_56.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 55,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_57.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 56,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_58.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 57,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_59.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 58,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_60.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 59,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_61.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 60,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_62.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 61,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_63.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 62,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_64.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 63,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_65.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 64,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_66.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 65,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_67.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 66,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_68.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 67,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_69.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 68,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_70.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 69,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_71.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 70,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_72.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 71,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_73.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 72,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_74.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 73,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_75.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 74,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_76.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 75,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_77.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 76,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_78.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 77,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_79.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 78,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_80.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 79,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_81.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 80,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_82.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 81,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_83.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 82,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_84.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 83,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_85.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 84,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_86.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 85,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_87.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 86,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_88.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 87,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_89.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 88,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_90.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 89,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_91.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 90,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_92.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 91,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_93.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 92,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_94.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 93,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_95.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 94,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_96.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 95,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_97.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 96,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_98.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 97,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_99.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'},
#   {'id': 98,
#    'width': 1280,
#    'height': 720,
#    'file_name': 'rgb_100.png',
#    'license': None,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': '0:00'}],
#  'annotations': [{'id': 0,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 0,
#    'category_id': 1},
#   {'id': 1,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 1,
#    'category_id': 1},
#   {'id': 2,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 2,
#    'category_id': 1},
#   {'id': 3,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 3,
#    'category_id': 1},
#   {'id': 4,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 4,
#    'category_id': 1},
#   {'id': 5,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 5,
#    'category_id': 1},
#   {'id': 6,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 6,
#    'category_id': 1},
#   {'id': 7,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 7,
#    'category_id': 1},
#   {'id': 8,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 8,
#    'category_id': 1},
#   {'id': 9,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 9,
#    'category_id': 1},
#   {'id': 10,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 10,
#    'category_id': 1},
#   {'id': 11,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 11,
#    'category_id': 1},
#   {'id': 12,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 12,
#    'category_id': 1},
#   {'id': 13,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 13,
#    'category_id': 1},
#   {'id': 14,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 14,
#    'category_id': 1},
#   {'id': 15,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 15,
#    'category_id': 1},
#   {'id': 16,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 16,
#    'category_id': 1},
#   {'id': 17,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 17,
#    'category_id': 1},
#   {'id': 18,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 18,
#    'category_id': 1},
#   {'id': 19,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 19,
#    'category_id': 1},
#   {'id': 20,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 20,
#    'category_id': 1},
#   {'id': 21,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 21,
#    'category_id': 1},
#   {'id': 22,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 22,
#    'category_id': 1},
#   {'id': 23,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 23,
#    'category_id': 1},
#   {'id': 24,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 24,
#    'category_id': 1},
#   {'id': 25,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 25,
#    'category_id': 1},
#   {'id': 26,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 26,
#    'category_id': 1},
#   {'id': 27,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 27,
#    'category_id': 1},
#   {'id': 28,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 28,
#    'category_id': 1},
#   {'id': 29,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 29,
#    'category_id': 1},
#   {'id': 30,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 30,
#    'category_id': 1},
#   {'id': 31,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 31,
#    'category_id': 1},
#   {'id': 32,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 32,
#    'category_id': 1},
#   {'id': 33,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 33,
#    'category_id': 1},
#   {'id': 34,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 34,
#    'category_id': 1},
#   {'id': 35,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 35,
#    'category_id': 1},
#   {'id': 36,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 36,
#    'category_id': 1},
#   {'id': 37,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 37,
#    'category_id': 1},
#   {'id': 38,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 38,
#    'category_id': 1},
#   {'id': 39,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 39,
#    'category_id': 1},
#   {'id': 40,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 40,
#    'category_id': 1},
#   {'id': 41,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 41,
#    'category_id': 1},
#   {'id': 42,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 42,
#    'category_id': 1},
#   {'id': 43,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 43,
#    'category_id': 1},
#   {'id': 44,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 44,
#    'category_id': 1},
#   {'id': 45,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 45,
#    'category_id': 1},
#   {'id': 46,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 46,
#    'category_id': 1},
#   {'id': 47,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 47,
#    'category_id': 1},
#   {'id': 48,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 48,
#    'category_id': 1},
#   {'id': 49,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 49,
#    'category_id': 1},
#   {'id': 50,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 50,
#    'category_id': 1},
#   {'id': 51,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 51,
#    'category_id': 1},
#   {'id': 52,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 52,
#    'category_id': 1},
#   {'id': 53,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 53,
#    'category_id': 1},
#   {'id': 54,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 54,
#    'category_id': 1},
#   {'id': 55,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 55,
#    'category_id': 1},
#   {'id': 56,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 56,
#    'category_id': 1},
#   {'id': 57,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 57,
#    'category_id': 1},
#   {'id': 58,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 58,
#    'category_id': 1},
#   {'id': 59,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 59,
#    'category_id': 1},
#   {'id': 60,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 60,
#    'category_id': 1},
#   {'id': 61,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 61,
#    'category_id': 1},
#   {'id': 62,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 62,
#    'category_id': 1},
#   {'id': 63,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 63,
#    'category_id': 1},
#   {'id': 64,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 64,
#    'category_id': 1},
#   {'id': 65,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 65,
#    'category_id': 1},
#   {'id': 66,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 66,
#    'category_id': 1},
#   {'id': 67,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 67,
#    'category_id': 1},
#   {'id': 68,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 68,
#    'category_id': 1},
#   {'id': 69,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 69,
#    'category_id': 1},
#   {'id': 70,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 70,
#    'category_id': 1},
#   {'id': 71,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 71,
#    'category_id': 1},
#   {'id': 72,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 72,
#    'category_id': 1},
#   {'id': 73,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 73,
#    'category_id': 1},
#   {'id': 74,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 74,
#    'category_id': 1},
#   {'id': 75,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 75,
#    'category_id': 1},
#   {'id': 76,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 76,
#    'category_id': 1},
#   {'id': 77,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 77,
#    'category_id': 1},
#   {'id': 78,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 78,
#    'category_id': 1},
#   {'id': 79,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 79,
#    'category_id': 1},
#   {'id': 80,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 80,
#    'category_id': 1},
#   {'id': 81,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 81,
#    'category_id': 1},
#   {'id': 82,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 82,
#    'category_id': 1},
#   {'id': 83,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 83,
#    'category_id': 1},
#   {'id': 84,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 84,
#    'category_id': 1},
#   {'id': 85,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 85,
#    'category_id': 1},
#   {'id': 86,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 86,
#    'category_id': 1},
#   {'id': 87,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 87,
#    'category_id': 1},
#   {'id': 88,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 88,
#    'category_id': 1},
#   {'id': 89,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 89,
#    'category_id': 1},
#   {'id': 90,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 90,
#    'category_id': 1},
#   {'id': 91,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 91,
#    'category_id': 1},
#   {'id': 92,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 92,
#    'category_id': 1},
#   {'id': 93,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 93,
#    'category_id': 1},
#   {'id': 94,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 94,
#    'category_id': 1},
#   {'id': 95,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 95,
#    'category_id': 1},
#   {'id': 96,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 96,
#    'category_id': 1},
#   {'id': 97,
#    'segmentation': None,
#    'iscrowd': 0,
#    'image_id': 97,
#    'category_id': 1}]}
